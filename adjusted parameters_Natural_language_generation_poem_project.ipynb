# %%
import os
# Prevent kernel from dying
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.util import ngrams
import string, time, math, random, sys, io, unicodedata

# For model testing
# !pip install rouge
from rouge import Rouge
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import SmoothingFunction
nltk.download('punkt')
# Out:
# Collecting rouge
#   Downloading https://files.pythonhosted.org/packages/43/cc/e18e33be20971ff73a056ebdb023476b5a545e744e3fc22acd8c758f1e0d/rouge-1.0.0-py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rouge) (1.15.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.python.keras.utils.data_utils import Sequence

# %%
MAX_SEQUENCE_LENGTH = 48
BATCH_SIZE = 24
N_EPOCHS = 64

# %%
from google.colab import drive
drive.mount('/content/drive')

# Reads the data
labeledPfd = pd.read_csv("/content/LabeledPoetryFoundationPoems.csv")

# Filters the poems by category
def get_poems_by_category(category):
    data = []
    for poem, emotion in zip(labeledPfd["poem"], labeledPfd["emotion"]):
        if emotion == category:
            data.append(poem)
    return data


# Gets the poems in each category
poems = {
    "joy": get_poems_by_category("joy"),
    "trust": get_poems_by_category("trust"),
    "sadness": get_poems_by_category("sadness"),
    "anticipation": get_poems_by_category("anticipation"),
    "fear": get_poems_by_category("fear"),
    "anger": get_poems_by_category("anger"),
    "disgust": get_poems_by_category("disgust"),
    "surprise": get_poems_by_category("surprise")
}
# Out:
# Mounted at /content/drive

# %%
class Vocabulary:
    def __init__(self):
        punctuation = " .,<>'();?!:-\"\n"
        digits = "0123456789"
        self.valid_chars = string.ascii_letters + punctuation + digits

        # Encodes the position of each character in the vocabulary
        self.char2idx = {word: i for i, word in enumerate(self.valid_chars)}
        self.idx2char = np.array(list(self.valid_chars))

    def __len__(self):
        return len(self.valid_chars)

    def chars(self):
        return self.valid_chars
    
    def isValidChar(self, char):
        return char in self.valid_chars
    
    def charToId(self, char):
        return self.char2idx[char]

    def idToChar(self, id):
        return self.idx2char[id]

# Forms the vocabulary shared accross all models
vocab = Vocabulary()


class DataProcessor:
    def __init__(self, dataset, repeat=0):
        self.batch_size = BATCH_SIZE
        self.seq_len = MAX_SEQUENCE_LENGTH
        full_data = list(dataset)

        # We have to use 50 poems for testing
        # because we used this number for our
        # previous deliverable as well.
        self.test_set = full_data[:50]
        full_data = full_data[50:]

        # Cleans the poems in the test-set
        clean_test_set = []
        for poem in self.test_set:
            clean_test_set.append( "".join(self.clean_single_poem(poem)) )
        self.test_set = clean_test_set
        
        # Cleans the data by removing
        # punctuation from the dataset
        self.clean_data = self.data_cleaner(full_data)

        # Transforms the entire text into integers
        text_as_int = np.array([vocab.charToId(c) for c in self.clean_data])

        # Create training examples / targets
        char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)
        sequences = char_dataset.batch(self.seq_len+1, drop_remainder=True)

        # Generates input-target pairs
        self.dataset = sequences.map(self.split_input_target)

        # Prints an example input-output pair
        print("Example Input-Target pair:")
        for input_example, target_example in self.dataset.take(1):
            print('  Input:  ', repr(''.join(vocab.idToChar(input_example.numpy()))))
            print('  Target: ', repr(''.join(vocab.idToChar(target_example.numpy()))))

        # Generates batches
        self.dataset = self.dataset.repeat(repeat + 1).batch(
            self.batch_size,
            drop_remainder=True
        )

        # Use 10% of the training dataset for validation
        tenPercent = math.ceil(len(dataset) * 0.1)
        self.val_inps = []
        self.val_tars = []
        val = self.dataset.take(tenPercent)
        self.dataset = self.dataset.skip(tenPercent)
        for val_inp, val_tar in val:
            self.val_inps.append(val_inp)
            self.val_tars.append(val_tar)

        # Print some useful info.
        print("Number of characters:", len(self.clean_data))
        print("Training batches: " + str(len(self.dataset)))



    def data_cleaner(self, poem_list):
        clean_data = []
        
        for poem in poem_list:
            clean_data += list(self.clean_single_poem(poem))
            
        return clean_data

    def clean_single_poem(self, poem):
        poem = self.unicodeToAscii(poem)
        clean_data = []

        # Adds the "poem start" symbol
        clean_data.append("<")

        for char in list(poem):
            # Converts tabs to spaces
            if char == "\t": char = " "

            prevChar = clean_data[len(clean_data) - 1]

            # Skips repeated "new line" characters and repeated spaces
            if vocab.isValidChar(char):
                if (char != "\n" and char != " ") or (char == "\n" and prevChar != "\n") or (char == " " and prevChar != " "):
                    clean_data.append(char)

        # Adds the "poem end" symbol
        clean_data.append(">")

        return clean_data

    def unicodeToAscii(self, s):
        # Turn a Unicode string to plain ASCII, thanks to
        # https://stackoverflow.com/a/518232/2809427
        return ''.join(
            c for c in unicodedata.normalize('NFD', s)
            if unicodedata.category(c) != 'Mn'
        )

    def split_input_target(self, chunk):
        input_text = chunk[:-1]
        target_text = chunk[1:]
        return input_text, target_text

# %%
class PoemModel:
    def __init__(self, data, weights=None, print_summary=False, recurrent_units=256,
                 embedding_size=128, dropout_rate=0.2):
        """
        Creates a trainable model.
        ::data - An instance of the `DataProcessor` class.
        ::batch_size - The size of the batches used for training the model. 32
            by default.
        ::weights - When this class is used for prediction, a set of weights
            must be provided from another model which was used for training.
        """

        self.data = data
        self.history = None

        # Global Hyperparameters
        self.recurrent_units = recurrent_units
        self.embedding_size = embedding_size
        self.dropout_rate = dropout_rate
        self.n_epochs = N_EPOCHS
        self.optimizer = keras.optimizers.RMSprop()
        self.loss_function = lambda labels, logits: keras.losses.sparse_categorical_crossentropy(
            labels, logits, from_logits=True
        )

        # Model-Specific Hyperparameters
        self.batch_size = BATCH_SIZE if weights == None else 1
        self.weights = weights

        # Creates the model
        self.model = self.__createModel()
        if (print_summary): self.model.summary()


    def train(self):
        """
        Trains the model using the provided data under the GPU
        provided by Google Colab.
        """
        with tf.device('/device:GPU:0'):
            model_callbacks = [
                # Reduces the learning rate if the model is having trouble
                # learning the data. This is applied after two epochs with
                # no improvement to the model's loss.
                tf.keras.callbacks.ReduceLROnPlateau(patience=2),
                # If even after reducing the learning rate the model still does
                # not improve, after 5 epochs of non-improving loss, the model
                # halts the training process.
                tf.keras.callbacks.EarlyStopping(patience=4)
            ]

            self.history = self.model.fit(
                self.data.dataset,
                epochs=self.n_epochs,
                callbacks=model_callbacks,
                validation_data=(self.data.val_inps, self.data.val_tars),
                verbose=1
            )


    def plot_loss(self, name):
        if (self.history != None):
            plt.plot(self.history.history['loss'])
            plt.plot(self.history.history['val_loss'])
            plt.title('Metrics for ' + name + ' model')
            plt.ylabel('loss')
            plt.xlabel('epoch')
            plt.legend(['train', 'test'], loc='upper left')
            plt.show()
        else:
            print("The model must be trained before the loss can be plotted.")


    def __createModel(self):
        """
        Creates an new sequential model with the specified
        hyperpearameters. If a set of weights (from anothe model)
        were provided, those weights are set for this model.
        """
        model = keras.models.Sequential([
            layers.Embedding(
                len(vocab),
                self.embedding_size,
                batch_input_shape=(self.batch_size, self.data.seq_len),
                name="EMBEDDING_layer"
            ),
            layers.Dense(len(vocab), activation="tanh", name="TANH_layer"),
            layers.GRU(
                self.recurrent_units,
                stateful=True,
                return_sequences=True,
                recurrent_initializer='glorot_uniform',
                name="GRU_layer"
            ),
            layers.Dropout(self.dropout_rate),
            layers.Dense(len(vocab), name="OUTPUT_layer")
        ])
        
        # If no wights were loaded into this model, we create a
        # new model from scratch. Otherwise we set the provided
        # wights into this model.
        if (self.weights == None):
            model.compile(loss=self.loss_function, optimizer=self.optimizer)
        else:
            model.set_weights(self.weights)
        
        # Returns the created model
        return model

# %%
class GeneratorModel:
    def __init__(self, trainedModel):
        self.trainedModel = trainedModel

        self.model = PoemModel(
            self.trainedModel.data,
            recurrent_units = self.trainedModel.recurrent_units,
            embedding_size = self.trainedModel.embedding_size,
            # Copies the trained weights into this model
            weights=trainedModel.model.get_weights(),
        )


    def generate(self, start_string, out_len, temperature=0.5):
        """
        Generates a new poem from the specified starting string.
        ::start_string - A seed string used for generating the new poem.
        ::out_len - The size (in characters) of the generated poem.
        ::temperature - The diversity of the generated text. If the number is
            low, the generated setences will look similar to the sentences it has
            seen before. If the number is high, the sentences will be more
            "original" (but may not look as perfect).
        """
        # Converting our start string to numbers (vectorizing)
        input_eval = [vocab.charToId(s) for s in start_string]
        input_eval = tf.expand_dims(input_eval, 0)

        # Empty string to store our results
        text_generated = []

        # Here batch size == 1
        # model.reset_states()
        for i in range(out_len):
            predictions = self.model.model(input_eval)
            # remove the batch dimension
            predictions = tf.squeeze(predictions, 0)

            # using a categorical distribution to predict
            # the character returned by the model
            predictions = predictions / temperature
            predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

            # Pass the predicted character as the next input to the model
            # along with the previous hidden state
            input_eval = tf.expand_dims([predicted_id], 0)

            predicted_char = vocab.idToChar(predicted_id)

            if predicted_char == ">":
                break
            else:
                text_generated.append(predicted_char)

        return (start_string + ''.join(text_generated))

# %%
def evaluate_model(model):
    rouge = Rouge()

    # cleans a peom
    def clean_poem(poem):
        return ["".join([char for char in word.lower() if vocab.isValidChar(char)])
                    for word in poem.split()]

    # list of poems with clean data as hypothesis for ROUGE
    rouge_hyp = [" ".join(clean_poem(poem)) for poem in model.model.data.test_set]
    rouge_refs = []

    # list of lists of poems with clean data as hypothesis for BLEU
    bleu_references = [clean_poem(poem) for poem in model.model.data.test_set]
    bleu_candidates = []

    chencherry = SmoothingFunction()

    for i in range(len(model.model.data.test_set)):
        first_chars = " ".join(list(rouge_hyp[i])[:MAX_SEQUENCE_LENGTH])
        gen_poem = model.generate(first_chars, 200, temperature=0.75)
        gen_poem = [word for word in nltk.word_tokenize(gen_poem)]

        # for rouge
        rouge_refs.append(" ".join(gen_poem))

        # for bleu
        bleu_candidates.append(gen_poem)

    rouge_scores = rouge.get_scores(rouge_hyp, rouge_refs, avg=True)
    print("ROUGE SCORE:", rouge_scores)

    bleu_score = corpus_bleu(bleu_references, bleu_candidates, smoothing_function=chencherry.method4)
    print("\nBLEU SCORE:", bleu_score)

# %%
print("VOCABULARY SIZE: " + str(len(vocab)))

print("\n\nJOY DATA =================================================")
joyData = DataProcessor(poems["joy"])

print("\n\nTRUST DATA ===============================================")
trustData = DataProcessor(poems["trust"])

print("\n\nSADNESS DATA =============================================")
sadnessData = DataProcessor(poems["sadness"])

print("\n\nANTICIPATION DATA ========================================")
anticipationData = DataProcessor(poems["anticipation"])

print("\n\nFEAR DATA ================================================")
fearData = DataProcessor(poems["fear"])

print("\n\nANGER DATA ===============================================")
angerData = DataProcessor(poems["anger"], repeat=1)

print("\n\nDISGUST DATA =============================================")
disgustData = DataProcessor(poems["disgust"], repeat=1)
# Out:
# VOCABULARY SIZE: 77
#
#
# JOY DATA =================================================
# Example Input-Target pair:
#   Input:   '<\nMany nights while walking home \nafter work, fr'
#   Target:  '\nMany nights while walking home \nafter work, fro'
# Number of characters: 6284418
# Training batches: 4914
#
#
# TRUST DATA ===============================================
# Example Input-Target pair:
#   Input:   '<\nIm standing in field 17 of the long series, em'
#   Target:  '\nIm standing in field 17 of the long series, emp'
# Number of characters: 7017910
# Training batches: 5542
#
#
# SADNESS DATA =============================================
# Example Input-Target pair:
#   Input:   '<\nWatts bleeds\nleaving stained reminders\non dust'
#   Target:  '\nWatts bleeds\nleaving stained reminders\non dusty'
# Number of characters: 1947888
# Training batches: 1478
#
#
# ANTICIPATION DATA ========================================
# Example Input-Target pair:
#   Input:   '<\nI carry my spikes and step on the field an hou'
#   Target:  '\nI carry my spikes and step on the field an hour'
# Number of characters: 1642098
# Training batches: 1236
#
#
# FEAR DATA ================================================
# Example Input-Target pair:
#   Input:   '<\nSome lamp sputters\nits dusty light\nacross some'
#   Target:  '\nSome lamp sputters\nits dusty light\nacross some '
# Number of characters: 1752978
# Training batches: 1348
#
#
# ANGER DATA ===============================================
# Example Input-Target pair:
#   Input:   '<\nCincinnati, Ohio, 1987\nRage is the language of'
#   Target:  '\nCincinnati, Ohio, 1987\nRage is the language of '
# Number of characters: 114328
# Training batches: 172
#
#
# DISGUST DATA =============================================
# Example Input-Target pair:
#   Input:   '<\nNothing nastier than a white person! \nShe mutt'
#   Target:  '\nNothing nastier than a white person! \nShe mutte'
# Number of characters: 38924
# Training batches: 54

# %%
joyModel = PoemModel(joyData, print_summary=True, recurrent_units=540, embedding_size=128)
print("\n")
joyModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
joyGenerator = GeneratorModel(joyModel)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 128)             9856
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              9933
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 540)             1002780
# _________________________________________________________________
# dropout_2 (Dropout)          (24, 48, 540)             0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              41657
# =================================================================
# Total params: 1,064,226
# Trainable params: 1,064,226
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 4914/4914 [==============================] - 45s 9ms/step - loss: 1.8812 - val_loss: 1.7645
# Epoch 2/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.7082 - val_loss: 1.7140
# Epoch 3/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.6734 - val_loss: 1.6829
# Epoch 4/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.6561 - val_loss: 1.6927
# Epoch 5/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.6464 - val_loss: 1.6707
# Epoch 6/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.6407 - val_loss: 1.6850
# Epoch 7/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.6375 - val_loss: 1.6711
# Epoch 8/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.6203 - val_loss: 1.6544
# Epoch 9/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.6049 - val_loss: 1.6481
# Epoch 10/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.5975 - val_loss: 1.6445
# Epoch 11/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.5922 - val_loss: 1.6435
# Epoch 12/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.5879 - val_loss: 1.6444
# Epoch 13/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.5843 - val_loss: 1.6441
# Epoch 14/64
# 4914/4914 [==============================] - 43s 9ms/step - loss: 1.5883 - val_loss: 1.6459
# Epoch 15/64
# 4914/4914 [==============================] - 42s 9ms/step - loss: 1.5862 - val_loss: 1.6456

# %%
trustModel = PoemModel(trustData, print_summary=True, recurrent_units=620, embedding_size=215)
print("\n")
trustModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
trustGenerator = GeneratorModel(trustModel)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 215)             16555
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              16632
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 620)             1300140
# _________________________________________________________________
# dropout_4 (Dropout)          (24, 48, 620)             0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              47817
# =================================================================
# Total params: 1,381,144
# Trainable params: 1,381,144
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 5542/5542 [==============================] - 59s 11ms/step - loss: 1.8637 - val_loss: 1.6718
# Epoch 2/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.6996 - val_loss: 1.6238
# Epoch 3/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.6667 - val_loss: 1.6095
# Epoch 4/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.6514 - val_loss: 1.5944
# Epoch 5/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.6437 - val_loss: 1.5910
# Epoch 6/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.6406 - val_loss: 1.6063
# Epoch 7/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.6395 - val_loss: 1.5992
# Epoch 8/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.6206 - val_loss: 1.5522
# Epoch 9/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.6037 - val_loss: 1.5415
# Epoch 10/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.5949 - val_loss: 1.5402
# Epoch 11/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.5888 - val_loss: 1.5341
# Epoch 12/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.5837 - val_loss: 1.5370
# Epoch 13/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5796 - val_loss: 1.5354
# Epoch 14/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5832 - val_loss: 1.5269
# Epoch 15/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5807 - val_loss: 1.5256
# Epoch 16/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5797 - val_loss: 1.5254
# Epoch 17/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5789 - val_loss: 1.5249
# Epoch 18/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5782 - val_loss: 1.5256
# Epoch 19/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5250
# Epoch 20/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5799 - val_loss: 1.5209
# Epoch 21/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5788 - val_loss: 1.5195
# Epoch 22/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5783 - val_loss: 1.5189
# Epoch 23/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5784 - val_loss: 1.5187
# Epoch 24/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5783 - val_loss: 1.5186
# Epoch 25/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5781 - val_loss: 1.5185
# Epoch 26/64
# 5542/5542 [==============================] - 57s 10ms/step - loss: 1.5781 - val_loss: 1.5185
# Epoch 27/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5781 - val_loss: 1.5185
# Epoch 28/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5780 - val_loss: 1.5183
# Epoch 29/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5181
# Epoch 30/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5780 - val_loss: 1.5180
# Epoch 31/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5782 - val_loss: 1.5179
# Epoch 32/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5778 - val_loss: 1.5178
# Epoch 33/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5178
# Epoch 34/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5177
# Epoch 35/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5176
# Epoch 36/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5176
# Epoch 37/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5780 - val_loss: 1.5176
# Epoch 38/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5780 - val_loss: 1.5176
# Epoch 39/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5778 - val_loss: 1.5176
# Epoch 40/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5777 - val_loss: 1.5176
# Epoch 41/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5778 - val_loss: 1.5176
# Epoch 42/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5176
# Epoch 43/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5176
# Epoch 44/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5778 - val_loss: 1.5176
# Epoch 45/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5779 - val_loss: 1.5176
# Epoch 46/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5778 - val_loss: 1.5176
# Epoch 47/64
# 5542/5542 [==============================] - 56s 10ms/step - loss: 1.5780 - val_loss: 1.5176

# %%
sadnessModel = PoemModel(sadnessData, print_summary=True, recurrent_units=700, embedding_size=350, dropout_rate=0.7)
print("\n")
sadnessModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
sadnessGenerator = GeneratorModel(trustModel)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 350)             26950
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              27027
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 700)             1635900
# _________________________________________________________________
# dropout_6 (Dropout)          (24, 48, 700)             0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              53977
# =================================================================
# Total params: 1,743,854
# Trainable params: 1,743,854
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 1478/1478 [==============================] - 18s 12ms/step - loss: 2.2013 - val_loss: 1.9877
# Epoch 2/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.9551 - val_loss: 1.8737
# Epoch 3/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.8823 - val_loss: 1.8264
# Epoch 4/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.8429 - val_loss: 1.7981
# Epoch 5/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.8130 - val_loss: 1.7740
# Epoch 6/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.7900 - val_loss: 1.7586
# Epoch 7/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.7707 - val_loss: 1.7458
# Epoch 8/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.7571 - val_loss: 1.7454
# Epoch 9/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.7451 - val_loss: 1.7413
# Epoch 10/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.7356 - val_loss: 1.7471
# Epoch 11/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.7279 - val_loss: 1.7490
# Epoch 12/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6989 - val_loss: 1.7085
# Epoch 13/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6788 - val_loss: 1.6988
# Epoch 14/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6698 - val_loss: 1.6968
# Epoch 15/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6633 - val_loss: 1.6974
# Epoch 16/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6575 - val_loss: 1.6988
# Epoch 17/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6568 - val_loss: 1.6869
# Epoch 18/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6539 - val_loss: 1.6822
# Epoch 19/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6530 - val_loss: 1.6801
# Epoch 20/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6514 - val_loss: 1.6790
# Epoch 21/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6506 - val_loss: 1.6786
# Epoch 22/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6502 - val_loss: 1.6780
# Epoch 23/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6495 - val_loss: 1.6773
# Epoch 24/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6491 - val_loss: 1.6766
# Epoch 25/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6484 - val_loss: 1.6767
# Epoch 26/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6480 - val_loss: 1.6762
# Epoch 27/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6472 - val_loss: 1.6762
# Epoch 28/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6468 - val_loss: 1.6757
# Epoch 29/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6458 - val_loss: 1.6758
# Epoch 30/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6457 - val_loss: 1.6756
# Epoch 31/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6454 - val_loss: 1.6755
# Epoch 32/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6450 - val_loss: 1.6749
# Epoch 33/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6445 - val_loss: 1.6758
# Epoch 34/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6441 - val_loss: 1.6753
# Epoch 35/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6437 - val_loss: 1.6737
# Epoch 36/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6434 - val_loss: 1.6725
# Epoch 37/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6429 - val_loss: 1.6715
# Epoch 38/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6430 - val_loss: 1.6709
# Epoch 39/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6428 - val_loss: 1.6705
# Epoch 40/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6431 - val_loss: 1.6700
# Epoch 41/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6429 - val_loss: 1.6697
# Epoch 42/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6427 - val_loss: 1.6693
# Epoch 43/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6422 - val_loss: 1.6692
# Epoch 44/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6428 - val_loss: 1.6691
# Epoch 45/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6420 - val_loss: 1.6691
# Epoch 46/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6428 - val_loss: 1.6689
# Epoch 47/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6424 - val_loss: 1.6689
# Epoch 48/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6423 - val_loss: 1.6688
# Epoch 49/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6420 - val_loss: 1.6688
# Epoch 50/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6418 - val_loss: 1.6688
# Epoch 51/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6426 - val_loss: 1.6688
# Epoch 52/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6419 - val_loss: 1.6687
# Epoch 53/64
# 1478/1478 [==============================] - 17s 12ms/step - loss: 1.6419 - val_loss: 1.6687
# Epoch 54/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6419 - val_loss: 1.6687
# Epoch 55/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6418 - val_loss: 1.6687
# Epoch 56/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6421 - val_loss: 1.6687
# Epoch 57/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6419 - val_loss: 1.6687
# Epoch 58/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6423 - val_loss: 1.6687
# Epoch 59/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6420 - val_loss: 1.6687
# Epoch 60/64
# 1478/1478 [==============================] - 17s 11ms/step - loss: 1.6420 - val_loss: 1.6687

# %%
anticipationModel = PoemModel(anticipationData, print_summary=True, recurrent_units=600, embedding_size=350, dropout_rate=0.5)
print("\n")
anticipationModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
anticipationGenerator = GeneratorModel(anticipationModel)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 350)             26950
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              27027
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 600)             1222200
# _________________________________________________________________
# dropout_8 (Dropout)          (24, 48, 600)             0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              46277
# =================================================================
# Total params: 1,322,454
# Trainable params: 1,322,454
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 1236/1236 [==============================] - 14s 11ms/step - loss: 2.1349 - val_loss: 1.7774
# Epoch 2/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.8750 - val_loss: 1.6899
# Epoch 3/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.8001 - val_loss: 1.6586
# Epoch 4/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.7577 - val_loss: 1.6311
# Epoch 5/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.7281 - val_loss: 1.6162
# Epoch 6/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.7046 - val_loss: 1.6134
# Epoch 7/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.6865 - val_loss: 1.6079
# Epoch 8/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.6704 - val_loss: 1.6093
# Epoch 9/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.6577 - val_loss: 1.6091
# Epoch 10/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.6258 - val_loss: 1.5637
# Epoch 11/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.6049 - val_loss: 1.5607
# Epoch 12/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5961 - val_loss: 1.5559
# Epoch 13/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5894 - val_loss: 1.5572
# Epoch 14/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5840 - val_loss: 1.5581
# Epoch 15/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5808 - val_loss: 1.5554
# Epoch 16/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5779 - val_loss: 1.5542
# Epoch 17/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5769 - val_loss: 1.5538
# Epoch 18/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5758 - val_loss: 1.5538
# Epoch 19/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5752 - val_loss: 1.5534
# Epoch 20/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5745 - val_loss: 1.5533
# Epoch 21/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5741 - val_loss: 1.5526
# Epoch 22/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5738 - val_loss: 1.5528
# Epoch 23/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5726 - val_loss: 1.5526
# Epoch 24/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5717 - val_loss: 1.5526
# Epoch 25/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5714 - val_loss: 1.5527
# Epoch 26/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5711 - val_loss: 1.5527
# Epoch 27/64
# 1236/1236 [==============================] - 13s 10ms/step - loss: 1.5718 - val_loss: 1.5527

# %%
fearModel = PoemModel(fearData, print_summary=True, recurrent_units=235, embedding_size=75)
print("\n")
fearModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
fearGenerator = GeneratorModel(fearModel)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 75)              5775
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              5852
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 235)             221370
# _________________________________________________________________
# dropout_10 (Dropout)         (24, 48, 235)             0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              18172
# =================================================================
# Total params: 251,169
# Trainable params: 251,169
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 1348/1348 [==============================] - 10s 7ms/step - loss: 2.2582 - val_loss: 2.1042
# Epoch 2/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.9908 - val_loss: 1.9912
# Epoch 3/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.9191 - val_loss: 1.9413
# Epoch 4/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.8807 - val_loss: 1.9194
# Epoch 5/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.8549 - val_loss: 1.9024
# Epoch 6/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.8364 - val_loss: 1.8969
# Epoch 7/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.8212 - val_loss: 1.8848
# Epoch 8/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.8101 - val_loss: 1.8780
# Epoch 9/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.8005 - val_loss: 1.8752
# Epoch 10/64
# 1348/1348 [==============================] - 9s 6ms/step - loss: 1.7924 - val_loss: 1.8666
# Epoch 11/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7859 - val_loss: 1.8658
# Epoch 12/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7800 - val_loss: 1.8593
# Epoch 13/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7746 - val_loss: 1.8633
# Epoch 14/64
# 1348/1348 [==============================] - 9s 6ms/step - loss: 1.7707 - val_loss: 1.8555
# Epoch 15/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7663 - val_loss: 1.8512
# Epoch 16/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7638 - val_loss: 1.8571
# Epoch 17/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7601 - val_loss: 1.8548
# Epoch 18/64
# 1348/1348 [==============================] - 9s 6ms/step - loss: 1.7542 - val_loss: 1.8154
# Epoch 19/64
# 1348/1348 [==============================] - 9s 7ms/step - loss: 1.7450 - val_loss: 1.8113
# Epoch 20/64
# 1348/1348 [==============================] - 9s 6ms/step - loss: 1.7419 - val_loss: 1.8117
# Epoch 21/64
# 1348/1348 [==============================] - 9s 7ms/step - loss: 1.7400 - val_loss: 1.8103
# Epoch 22/64
# 1348/1348 [==============================] - 9s 7ms/step - loss: 1.7384 - val_loss: 1.8100
# Epoch 23/64
# 1348/1348 [==============================] - 9s 7ms/step - loss: 1.7371 - val_loss: 1.8108
# Epoch 24/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7356 - val_loss: 1.8107
# Epoch 25/64
# 1348/1348 [==============================] - 9s 6ms/step - loss: 1.7365 - val_loss: 1.8046
# Epoch 26/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7349 - val_loss: 1.8024
# Epoch 27/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7341 - val_loss: 1.8013
# Epoch 28/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7342 - val_loss: 1.8004
# Epoch 29/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7335 - val_loss: 1.8000
# Epoch 30/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7335 - val_loss: 1.7997
# Epoch 31/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7336 - val_loss: 1.7996
# Epoch 32/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7332 - val_loss: 1.7995
# Epoch 33/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7333 - val_loss: 1.7993
# Epoch 34/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7334 - val_loss: 1.7989
# Epoch 35/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7328 - val_loss: 1.7987
# Epoch 36/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7328 - val_loss: 1.7989
# Epoch 37/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7329 - val_loss: 1.7984
# Epoch 38/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7324 - val_loss: 1.7987
# Epoch 39/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7323 - val_loss: 1.7988
# Epoch 40/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7314 - val_loss: 1.7984
# Epoch 41/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7326 - val_loss: 1.7981
# Epoch 42/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7314 - val_loss: 1.7979
# Epoch 43/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7316 - val_loss: 1.7978
# Epoch 44/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7322 - val_loss: 1.7978
# Epoch 45/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7320 - val_loss: 1.7977
# Epoch 46/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7319 - val_loss: 1.7977
# Epoch 47/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7315 - val_loss: 1.7977
# Epoch 48/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7317 - val_loss: 1.7976
# Epoch 49/64
# 1348/1348 [==============================] - 9s 6ms/step - loss: 1.7320 - val_loss: 1.7976
# Epoch 50/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7319 - val_loss: 1.7976
# Epoch 51/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7319 - val_loss: 1.7976
# Epoch 52/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7317 - val_loss: 1.7976
# Epoch 53/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7323 - val_loss: 1.7976
# Epoch 54/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7315 - val_loss: 1.7976
# Epoch 55/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7317 - val_loss: 1.7976
# Epoch 56/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7325 - val_loss: 1.7976
# Epoch 57/64
# 1348/1348 [==============================] - 8s 6ms/step - loss: 1.7316 - val_loss: 1.7976

# %%
angerModel = PoemModel(angerData, print_summary=True, recurrent_units=1000,
                       embedding_size=75, dropout_rate=0.1)
print("\n")
angerModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
angerGenerator = GeneratorModel(angerModel)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 75)              5775
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              5852
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 1000)            3237000
# _________________________________________________________________
# dropout_14 (Dropout)         (24, 48, 1000)            0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              77077
# =================================================================
# Total params: 3,325,704
# Trainable params: 3,325,704
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 172/172 [==============================] - 3s 20ms/step - loss: 2.7235 - val_loss: 2.3356
# Epoch 2/64
# 172/172 [==============================] - 3s 17ms/step - loss: 2.2723 - val_loss: 2.1665
# Epoch 3/64
# 172/172 [==============================] - 3s 17ms/step - loss: 2.1194 - val_loss: 2.0213
# Epoch 4/64
# 172/172 [==============================] - 3s 17ms/step - loss: 1.9744 - val_loss: 1.9087
# Epoch 5/64
# 172/172 [==============================] - 3s 17ms/step - loss: 1.8000 - val_loss: 1.7982
# Epoch 6/64
# 172/172 [==============================] - 3s 17ms/step - loss: 1.5803 - val_loss: 1.6730
# Epoch 7/64
# 172/172 [==============================] - 3s 17ms/step - loss: 1.3123 - val_loss: 1.5222
# Epoch 8/64
# 172/172 [==============================] - 3s 17ms/step - loss: 1.0177 - val_loss: 1.3626
# Epoch 9/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.7421 - val_loss: 1.2281
# Epoch 10/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.5250 - val_loss: 1.0735
# Epoch 11/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.3844 - val_loss: 0.9718
# Epoch 12/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.2943 - val_loss: 0.9099
# Epoch 13/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.2394 - val_loss: 0.8861
# Epoch 14/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.1993 - val_loss: 0.8233
# Epoch 15/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.1749 - val_loss: 0.8361
# Epoch 16/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.1577 - val_loss: 0.8495
# Epoch 17/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.1331 - val_loss: 0.7746
# Epoch 18/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.0810 - val_loss: 0.7573
# Epoch 19/64
# 172/172 [==============================] - 3s 17ms/step - loss: 0.0633 - val_loss: 0.7543
# Epoch 20/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.0525 - val_loss: 0.7465
# Epoch 21/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.0445 - val_loss: 0.7579
# Epoch 22/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.0391 - val_loss: 0.7524
# Epoch 23/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.0375 - val_loss: 0.7504
# Epoch 24/64
# 172/172 [==============================] - 3s 18ms/step - loss: 0.0353 - val_loss: 0.7518

# %%
disgustModel = PoemModel(disgustData, print_summary=True, recurrent_units=650,
                         embedding_size=320, dropout_rate=0.9)
print("\n")
disgustModel.train()

# Because we trained the model using batch sizes specified in the
# BATCH_SIZE variable, using the original model will also require
# inputs of BATCH_SIZE in order to make a prediction. Because of that,
# we must create a new model whose batch_size is set to 1, and copy
# the weights from the original model into this prediction model.
disgustGenerator = GeneratorModel(disgustModel)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING_layer (Embedding)  (24, 48, 320)             24640
# _________________________________________________________________
# TANH_layer (Dense)           (24, 48, 77)              24717
# _________________________________________________________________
# GRU_layer (GRU)              (24, 48, 650)             1421550
# _________________________________________________________________
# dropout_16 (Dropout)         (24, 48, 650)             0
# _________________________________________________________________
# OUTPUT_layer (Dense)         (24, 48, 77)              50127
# =================================================================
# Total params: 1,521,034
# Trainable params: 1,521,034
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/64
# 54/54 [==============================] - 1s 27ms/step - loss: 3.2902 - val_loss: 2.7532
# Epoch 2/64
# 54/54 [==============================] - 1s 11ms/step - loss: 2.7313 - val_loss: 2.6286
# Epoch 3/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.6174 - val_loss: 2.5545
# Epoch 4/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.5503 - val_loss: 2.4948
# Epoch 5/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.5082 - val_loss: 2.4653
# Epoch 6/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.4696 - val_loss: 2.4386
# Epoch 7/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.4369 - val_loss: 2.4070
# Epoch 8/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.4171 - val_loss: 2.3780
# Epoch 9/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.3950 - val_loss: 2.3659
# Epoch 10/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.3764 - val_loss: 2.3469
# Epoch 11/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.3567 - val_loss: 2.3251
# Epoch 12/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.3375 - val_loss: 2.3109
# Epoch 13/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.3252 - val_loss: 2.2930
# Epoch 14/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.3068 - val_loss: 2.2773
# Epoch 15/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.2832 - val_loss: 2.2596
# Epoch 16/64
# 54/54 [==============================] - 1s 11ms/step - loss: 2.2792 - val_loss: 2.2532
# Epoch 17/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.2606 - val_loss: 2.2339
# Epoch 18/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.2440 - val_loss: 2.2242
# Epoch 19/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.2291 - val_loss: 2.2127
# Epoch 20/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.2112 - val_loss: 2.1972
# Epoch 21/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.1957 - val_loss: 2.1854
# Epoch 22/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.1796 - val_loss: 2.1740
# Epoch 23/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.1667 - val_loss: 2.1537
# Epoch 24/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.1435 - val_loss: 2.1411
# Epoch 25/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.1250 - val_loss: 2.1313
# Epoch 26/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.1038 - val_loss: 2.1163
# Epoch 27/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.0883 - val_loss: 2.1050
# Epoch 28/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.0682 - val_loss: 2.0909
# Epoch 29/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.0391 - val_loss: 2.0768
# Epoch 30/64
# 54/54 [==============================] - 1s 12ms/step - loss: 2.0215 - val_loss: 2.0428
# Epoch 31/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.9968 - val_loss: 2.0390
# Epoch 32/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.9714 - val_loss: 2.0183
# Epoch 33/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.9494 - val_loss: 2.0023
# Epoch 34/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.9216 - val_loss: 1.9824
# Epoch 35/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.8909 - val_loss: 1.9510
# Epoch 36/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.8689 - val_loss: 1.9719
# Epoch 37/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.8427 - val_loss: 1.9406
# Epoch 38/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.8191 - val_loss: 1.9237
# Epoch 39/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.7913 - val_loss: 1.9038
# Epoch 40/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.7633 - val_loss: 1.8709
# Epoch 41/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.7369 - val_loss: 1.8490
# Epoch 42/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.7114 - val_loss: 1.8544
# Epoch 43/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.6880 - val_loss: 1.8139
# Epoch 44/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.6578 - val_loss: 1.8230
# Epoch 45/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.6389 - val_loss: 1.7961
# Epoch 46/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.6144 - val_loss: 1.7792
# Epoch 47/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.5900 - val_loss: 1.7358
# Epoch 48/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.5677 - val_loss: 1.7353
# Epoch 49/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.5435 - val_loss: 1.7318
# Epoch 50/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.5153 - val_loss: 1.6840
# Epoch 51/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.4997 - val_loss: 1.6711
# Epoch 52/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.4770 - val_loss: 1.6494
# Epoch 53/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.4626 - val_loss: 1.6440
# Epoch 54/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.4387 - val_loss: 1.6271
# Epoch 55/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.4129 - val_loss: 1.5957
# Epoch 56/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.4010 - val_loss: 1.5706
# Epoch 57/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.3772 - val_loss: 1.5776
# Epoch 58/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.3604 - val_loss: 1.5961
# Epoch 59/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.2920 - val_loss: 1.4971
# Epoch 60/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.2485 - val_loss: 1.4766
# Epoch 61/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.2180 - val_loss: 1.4721
# Epoch 62/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.2012 - val_loss: 1.4621
# Epoch 63/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.1838 - val_loss: 1.4593
# Epoch 64/64
# 54/54 [==============================] - 1s 12ms/step - loss: 1.1716 - val_loss: 1.4537

# %%
# Sometimes the ROUGE scoring needs a larger
# recursion depth. We reset the recursive
# limit to be higher. In case the limit is
# too low for the current test.
defaultRecursionDepth = sys.getrecursionlimit()
sys.setrecursionlimit(defaultRecursionDepth * 100)

print("JOY EVALUTATION =================================================")
evaluate_model(joyGenerator)
print("\nExample Poem: " + joyGenerator.generate("<Love", 100, temperature=0.8))
print("\n")
joyModel.plot_loss("Joy")

print("\n\nTRUST EVALUTATION ===========================================")
evaluate_model(trustGenerator)
print("\nExample Poem: " + trustGenerator.generate("<Feel", 100, temperature=0.8))
print("\n")
trustModel.plot_loss("Trust")

print("\n\nSADNESS EVALUTATION =========================================")
evaluate_model(sadnessGenerator)
print("\nExample Poem: " + sadnessGenerator.generate("<Tear", 100, temperature=0.8))
print("\n")
sadnessModel.plot_loss("Sadness")

print("\n\nANTICIPATION EVALUTATION ====================================")
evaluate_model(anticipationGenerator)
print("\nExample Poem: " + anticipationGenerator.generate("<Hope", 100, temperature=0.8))
print("\n")
anticipationModel.plot_loss("Anticipation")

print("\n\nFEAR EVALUTATION ============================================")
evaluate_model(fearGenerator)
print("\nExample Poem: " + fearGenerator.generate("<Fear", 100, temperature=0.8))
print("\n")
fearModel.plot_loss("Fear")

print("\n\nANGER EVALUTATION ===========================================")
evaluate_model(angerGenerator)
print("\nExample Poem: " + angerGenerator.generate("<Rage", 100, temperature=0.8))
print("\n")
angerModel.plot_loss("Anger")

print("\n\nDISGUST EVALUTATION =========================================")
evaluate_model(disgustGenerator)
print("\nExample Poem: " + disgustGenerator.generate("<Guts", 100, temperature=0.8))
print("\n")
disgustModel.plot_loss("Disgust")

# Reset the recursion depth after we are done
# testing, so that other parts of the program
# do not take advantage of it.
sys.setrecursionlimit(defaultRecursionDepth)
# Out:
# JOY EVALUTATION =================================================
# ROUGE SCORE: {'rouge-1': {'f': 0.12426045993411633, 'p': 0.0973667735626897, 'r': 0.20425180020908965}, 'rouge-2': {'f': 0.0067385417579678706, 'p': 0.005095720293005158, 'r': 0.011972933866623786}, 'rouge-l': {'f': 0.09733702863917117, 'p': 0.07331639883333403, 'r': 0.16809554548122865}}
#
# BLEU SCORE: 0.27745373226326747
#
# Example Poem: <Love with God have endured.
# Sweet to a cowall and the complete shoulder; The sea has made you to you, n
# TRUST EVALUTATION ===========================================
# ROUGE SCORE: {'rouge-1': {'f': 0.13429006116863285, 'p': 0.1079238640026381, 'r': 0.22735518309896097}, 'rouge-2': {'f': 0.008779360970678144, 'p': 0.007039103932219714, 'r': 0.015987503273543542}, 'rouge-l': {'f': 0.10491704408408169, 'p': 0.08089895653666096, 'r': 0.18818183999035565}}
#
# BLEU SCORE: 0.2748421984990375
#
# Example Poem: <Feeling so high or the desurt.
# She was not at the wazed toarses of her lifelite. The glass of ground dis
# SADNESS EVALUTATION =========================================
# ROUGE SCORE: {'rouge-1': {'f': 0.1308152887638958, 'p': 0.10441547296877551, 'r': 0.22263018555912253}, 'rouge-2': {'f': 0.00951914785557739, 'p': 0.007192094402812682, 'r': 0.01885703226395639}, 'rouge-l': {'f': 0.10456645240089381, 'p': 0.08037111885689892, 'r': 0.18409851655514667}}
#
# BLEU SCORE: 0.2721297940654354
#
# Example Poem: <Tears in the street of the seas and the other is Deet will dare with print throwgh e pink falls, the tre
# ANTICIPATION EVALUTATION ====================================
# ROUGE SCORE: {'rouge-1': {'f': 0.13347445500914035, 'p': 0.11074698779043675, 'r': 0.2216854977011314}, 'rouge-2': {'f': 0.007404950926097015, 'p': 0.005914309147269394, 'r': 0.014592462660627201}, 'rouge-l': {'f': 0.10232383009571498, 'p': 0.07956337812723752, 'r': 0.17910502079259402}}
#
# BLEU SCORE: 0.2801781081313788
#
# Example Poem: <Hope that was meing a motion that he said, perhaps was the long get up to be spant, leave it once
# wn be
# FEAR EVALUTATION ============================================
# ROUGE SCORE: {'rouge-1': {'f': 0.13180785648756432, 'p': 0.11096987082965497, 'r': 0.20124123782856032}, 'rouge-2': {'f': 0.00967014966876981, 'p': 0.007693014900169493, 'r': 0.01595201156522762}, 'rouge-l': {'f': 0.10464977036979191, 'p': 0.08438156840933674, 'r': 0.1678542777244164}}
#
# BLEU SCORE: 0.27505300962802726
#
# Example Poem: <Fearsheer through the catch ma,
#  The search so Now everyll grives,
# letter eldervil
#
# In the incwerved s
# ANGER EVALUTATION ===========================================
# ROUGE SCORE: {'rouge-1': {'f': 0.09860320426288047, 'p': 0.09753508139095893, 'r': 0.13835190947468204}, 'rouge-2': {'f': 0.00442846745642038, 'p': 0.003903617176092006, 'r': 0.006992859399320269}, 'rouge-l': {'f': 0.08818871884732613, 'p': 0.07801447211123166, 'r': 0.13608093718310196}}
#
# BLEU SCORE: 0.3070328345904618
#
# Example Poem: <Rage its slieving my below Jude tired line that stood before; There revenges are for the Alm
#  Ind if in
# DISGUST EVALUTATION =========================================
# ROUGE SCORE: {'rouge-1': {'f': 0.10290530682434089, 'p': 0.10848936266546531, 'r': 0.14069366128265004}, 'rouge-2': {'f': 0.0038944098363114404, 'p': 0.003664832151817797, 'r': 0.0057775293056385665}, 'rouge-l': {'f': 0.08835858599680524, 'p': 0.08618525616225042, 'r': 0.12627589813287435}}
#
# BLEU SCORE: 0.2907754852179414
#
# Example Poem: <Gutseon of ilshere whoch the minol aarom-
# of 1Che smovel you bool of of sopself.

# %%
def generate_poem_MIL(cat, seed, outlen, creativeness):
    cat = cat.lower()
    model = None

    # Only accepts arguments between 0-1 for the creativeness
    creativeness = creativeness if creativeness > 0 else 0
    creativeness = creativeness if creativeness < 1 else 1
    # The "creativeness" parameter accepts a float between 0-1,
    # but we linearly map that number to be between 0.4 and 1,
    # since a temperature outside that range tends to yield
    # nonsensical sequences.
    creativeness = (0.6 * creativeness) + 0.4

    # Chooses the apropriate model based
    # on the provided category
    if cat == "joy":
        model = joyGenerator
    elif cat == "trust":
        model = trustGenerator
    elif cat == "sadness":
        model = sadnessGenerator
    elif cat == "anticipation":
        model = anticipationGenerator
    elif cat == "fear":
        model = fearGenerator
    elif cat == "anger":
        model = angerGenerator
    elif cat == "disgust":
        model = disgustGenerator
    else:
        # The user must provide a valid category
        # in order to generate any poems
        return None
    
    return model.generate(seed, outlen, temperature=creativeness)

# %%
def MIL():
    emotion = ""
    seed = ""
    outlen = 0
    creativeness = 0

    # Gets the seed
    while True:
        answer = input(":: Provied a start for the poem: \n>> ")

        if len(answer) > 0:
            seed = answer
            break
        else:
            print("\n:: Please provide at leat one character for the poem's start.")

    # Get the generated length
    while True:
        answer = input("\n\n:: How many characters long should the poem be? \n>> ")

        try:
            outlen = int(answer)
            break
        except ValueError:
            print("\n:: Please provide a valid integer.")

    # Get the creativeness
    while True:
        answer = input("\n\n:: How creative should the model be? (0-1)\n>> ")

        try:
            if float(answer) >= 0 and float(answer) <= 1:
                creativeness = float(answer)
                break
            else:
                print(":: Please provide a valid float between 0 and 1.")
        except ValueError:
            print(":: Please provide a valid float between 0 and 1.")

    # Get the emotion
    def emo():
        cat = None
        while True:
            answer = input("\n\n:: Please select an emotion from the following:\n   "+
                        "[joy, trust, sadness, anticipation, fear, anger, disgust]\n>> ")
            
            if answer in ["joy","trust","sadness","anticipation","fear","anger","disgust"]:
                cat = answer
                break
            else:
                print("\n:: Please provide a valid emotion.")
        return cat

    emotion = emo()

    def p():
        print("\n\n\n================\n" +
            str(generate_poem_MIL(emotion, seed, outlen, creativeness)) +
            "\n================\n")
    p()

    # Generate poems
    while True:
        option = input("\n\n:: Please select an action: "+
              "\na) Choose another emotion\nb) Generate new poem\nc) Stop\n>> ")
        
        if option in ["a", "b", "c"]:
            if option == "a":
                emotion = emo()
                p()
            elif option == "b":
                p()
            elif option == "c":
                break
        else:
            print("please select a valid option")

# %%
MIL()
# Out:
# :: Provied a start for the poem:
# >> he
#
#
# :: How many characters long should the poem be?
# >> 500
#
#
# :: How creative should the model be? (0-1)
# >> .3
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> joy
#
#
#
# ================
# he falling tender things.
# I have the very shine of the cheese where the silent space is never that this she is shadows and the day placed at her face of mistake to grass how to speak the little power of years with war and months and crystal grass.
# The streams of place and country in children to the shower.
# It was the little brow of the bare you will be ready, Im not a woman who have a party beauty,
#  A man content to hold our peeling parts and voice to the dead electric portal unseen or bird
# which
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> a
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> trust
#
#
#
# ================
# hes hands that can see the heart of earth and liberty with the trees the stairs and raised her promising of e are made or processed the company the same year of the great bed, and the path of the bathtorn the teachers shadow like a little mouth
# hearts in the strong man like we loved the river
# and the including the earth that so exactly, faces of the trees but camera are still a cup of heaven and look to observed to water to the trees.
# One more in the armed light of the door
# for your face and send
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> a
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> sadness
#
#
#
# ================
# he bright same white words We should see present, and lean in the backward meat, on his grandfather who heard the common man.
#
# he matters in fact I only miss what I said, and if we were still watching the river and the star and the man becomes a fine
# book of the wind was gone.
# What among the moon that keeps me, and the same as if not a selected from the armpotent at the wind was a piece of stars.
#
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> a
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> anticipation
#
#
#
# ================
# he said, who was not the part of point, and the dort bringes here by the end hat silently at the market for a time and the green way the eyes stopped and says they were to the first light that days and wanting to have the world is a field, the conversation of his time, his telescope of houses like the same,
#
# Of the sun as the way the street children were corning something on the dreams
# But this is the sound of his hair.
# The shadows see the provident with brought the cheek, and the hand, and star
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> a
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> fear
#
#
#
# ================
# he played chaining in the world.
# No should have a mothers with my still sees to the other stream of a stars gather the shows and the sun. As the one was a mental of some percace of shadows leaves the way the shore see, the dead worth of the spoke to the words was summer, the faces was said,
# And we saw the earth of which the lights from the arm to do the postion and bare the light. And the circle and the nearest the garden to the floor of the farm of fire because she said the way to find the single
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> a
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> anger
#
#
#
# ================
# he water
#  jumps from their mouths.
#  Jaws of meat, or a tail of fishin gouse the drain in spirals
# In the last rinu of demories,
# This is the place they brouth a clif in the whole its episode trailing,
# pretending to be a thine recovering; tarmac tongue ticks in the black the pool
# He slaps the plane 10 times this year
# and ithered trick in the blue thing
# Along negligence
#
# Charpling griel oner he sed, my east many wonder what I would have said
# if the fest silver spiery screams into dy dogilin, voice i
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> a
#
#
# :: Please select an emotion from the following:
#    [joy, trust, sadness, anticipation, fear, anger, disgust]
# >> disgust
#
#
#
# ================
# he cause the pan
# courly wither with a sreat were fullon we saunk you wengh me with ome stanted pelfs of the stine of blows and the sandions and rield at thou freath, fut her my I cat water kanks honer and roant that hast donde, I dade
# being the mants afing to thou hotsen with tale to lot
# But bird on the sotter of nothenging what you and jist of airess merat on I wanth a sond he sales wine shis and a billing to thou host tise to fat and not roats, and sluw filts the sare uf bug and the sis, dore,
#
# ================
#
#
#
# :: Please select an action:
# a) Choose another emotion
# b) Generate new poem
# c) Stop
# >> c
